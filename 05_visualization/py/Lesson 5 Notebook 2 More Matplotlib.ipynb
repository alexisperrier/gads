# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)


df = pd.read_csv('../data/ozone.csv')
df.shape
# Out:
# (153, 6)

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41      190   7.4    67      5    1
# 1     36      118   8.0    72      5    2
# 2     12      149  12.6    74      5    3
# 3     18      313  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5

# %%
df = df.dropna()

# %%
# Using plt.hist, draw 4 subplots, each with histogram and density
# labeled, titled, nice axes, ...

# %%
fig, ax = plt.subplots(2,2, figsize=(12,12))


# 1st subplot
plt.subplot(221)
ax = plt.gca()
ax.set_axis_bgcolor('white')
df.Ozone.plot(kind='hist', secondary_y=True, label="hist", legend=True, bins = 30)
df.Ozone.plot(kind='density', label="density", legend=True)
plt.title('Ozone')
plt.grid()

# 2nd subplot

plt.subplot(222)
ax = plt.gca()
ax.set_axis_bgcolor('white')
df.Wind.plot(kind='hist', secondary_y=True, label="hist", legend=True, bins = 30)
df.Wind.plot(kind='density', label="density", legend=True)
plt.title('Wind')
plt.grid()

# 3rd subplot

plt.subplot(223)
ax = plt.gca()
ax.set_axis_bgcolor('white')
df['Solar.R'].plot(kind='hist', secondary_y=True, label="hist", legend=True, bins = 30)
df['Solar.R'].plot(kind='density', label="density", legend=True)
plt.title('Solar.R')
plt.grid()

# 4th subplot

plt.subplot(224)
ax = plt.gca()
ax.set_axis_bgcolor('white')
df.Temp.plot(kind='hist', secondary_y=True, label="hist", legend=True, bins = 30)
df.Temp.plot(kind='density', label="density", legend=True)
plt.title('Temp')
plt.grid()

# %%
df[['Ozone','Solar.R','Wind','Temp']].corr()
# Out:
#             Ozone   Solar.R      Wind      Temp
# Ozone    1.000000  0.348342 -0.612497  0.698541
# Solar.R  0.348342  1.000000 -0.127183  0.294088
# Wind    -0.612497 -0.127183  1.000000 -0.497190
# Temp     0.698541  0.294088 -0.497190  1.000000

# %%
# Scatter plot with Temp vs Ozone

fig = plt.figure()

plt.scatter(df.Ozone, df.Wind, s=df['Solar.R'],  c=df.Temp, cmap=plt.cm.coolwarm)

# plt.grid()
ax = plt.gca()

ax.set_axis_bgcolor('white')
plt.xlabel('Wind')
plt.ylabel('Ozone')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['bottom'].set_color('none')

plt.show()
