# %% [markdown]
# # Part I: Support vector Classifier
#
#
#
# Scikit: http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score
from sklearn.grid_search import GridSearchCV

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.svm import SVC

np.random.seed(8)


def plot_svc(svc, X, y, h=0.02, pad=0.25):
    x_min, x_max = X[:, 0].min()-pad, X[:, 0].max()+pad
    y_min, y_max = X[:, 1].min()-pad, X[:, 1].max()+pad
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.2)

    plt.scatter(X[:,0], X[:,1], s=70, c=y, cmap=plt.cm.Paired)
    # Support vectors indicated in plot by vertical lines
    sv = svc.support_vectors_
    plt.scatter(sv[:,0], sv[:,1], c='k', marker='|', s=100, linewidths='1')
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.show()
    print('Number of support vectors: ', svc.support_.size)

# %% [markdown]
# # Generate the data and plot it

# %%
# Generating random data: 20 observations of 2 features and divide into two classes.
# Training data
np.random.seed(5)
X = np.random.randn(20,2)
y = np.repeat([1,-1], 10)

# Move the class -1  by one unit to separate the 2 classes but not entirely
X[y == -1] = X[y == -1] +1

# Plot training data
plt.scatter(X[:,0], X[:,1], s=70, c=y, cmap=plt.cm.Paired)
plt.xlabel('X1')
plt.ylabel('X2');

# %% [markdown]
# # Support Vector Classifier with linear kernel.
#
# * Train a SVC
# * Use a linear Kernel
# * Try out several values for C
# * plot using plot_svc
#
# Number of support vectors as a function of C?

# %% [markdown]
# # Find best C - Linear kernel
#
# tuned_parameters = [{'C': [0.001, 0.01, 0.1, 1, 5, 10, 100]}]
# with GridSearchCV, K-fold = 10 and accuracy

# %% [markdown]
# # Generate test data

# %%
# Generating test data
np.random.seed(1)
X_test = np.random.randn(20,2)
y_test = np.random.choice([-1,1], 20)

# This time move the 1 class to separate the  2 classes but not entirely
X_test[y_test == 1] = X_test[y_test == 1] -1

plt.scatter(X_test[:,0], X_test[:,1], s=70, c=y_test, cmap=plt.cm.Paired)
plt.xlabel('X1')
plt.ylabel('X2');

# %% [markdown]
# # Model Performance:
#
# Apply the best SVC to the test dataset
#
# What's the confusion matrix

# %% [markdown]
# ### Linearly Separable data

# %%
# Changing the test data so that the classes are really separable with a hyperplane.

X_test[y_test == 1] = X_test[y_test == 1] -1

plt.scatter(X_test[:,0], X_test[:,1], s=70, c=y_test, cmap=plt.cm.Paired)
plt.xlabel('X1')
plt.ylabel('X2');

# %% [markdown]
# # Performance for different models
#
# Fit a SVC (linear) for C = 1 and C = 10
#
# * Misclassification?
# * Number of support vectors?
# * Accuracy? Confusion Matrix?
