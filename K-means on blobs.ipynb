# %%
import numpy as np
import pandas as pd

from sklearn import cluster, datasets
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score
from sklearn.grid_search import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('fivethirtyeight')
np.random.seed(8)

# %%
n_samples = 1500
np.random.seed(809)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)

noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)
no_structure = np.random.rand(n_samples, 2), None

X, y = blobs
X = StandardScaler().fit_transform(X)

# k means fitting
color_dict = {0:'r', 1:'b', 2:'y', 3:'m', 4:'g'}

color_list = [color_dict[c] for c in y_pred]

for k in [2,3,4,5]:
    kmeans = cluster.KMeans(n_clusters=k)
    dbscan = cluster.DBSCAN(eps=.2)
    spectral = cluster.SpectralClustering(n_clusters=2, eigen_solver='arpack', affinity="nearest_neighbors")
    clst = kmeans

    clst.fit(X)

    y_pred = clst.labels_.astype(np.int)


    plt.scatter(X[:, 0], X[:, 1], color=color_list, s=10)


    print("k = %s Inertia: %0.2f"% (k, kmeans.inertia_ * k))
# Out:
# k = 2 Inertia: 736.38
# k = 3 Inertia: 190.43
# k = 4 Inertia: 216.44
# k = 5 Inertia: 229.77
# /Users/aperrier/anaconda/envs/py34/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
